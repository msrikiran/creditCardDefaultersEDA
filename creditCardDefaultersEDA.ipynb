# %% [markdown]
# https://drive.google.com/drive/folders/14GB0zlmL6DMdFb2eGVbY3JiB1UtJlP2N?usp=sharing
#
# download the dataset and problem statement here

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Read the excel sheet directly from the google drive
import pandas as pd

url='https://drive.google.com/file/d/1x4lB2unLvsboOx-QoENbz9TL-Rys5dmR/view?usp=sharing'
file_id=url.split('/')[-2]
dwn_url='https://drive.google.com/uc?id=' + file_id

# %%
df = pd.read_excel(dwn_url)

# %%
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0         0         0         0                           1
# 1      1000         0      2000                           1
# 2      1000      1000      5000                           0
# 3      1100      1069      1000                           0
# 4      9000       689       679                           0
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (30000, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# BILL_AMT5                     30000 non-null int64
# BILL_AMT6                     30000 non-null int64
# PAY_AMT1                      30000 non-null int64
# PAY_AMT2                      30000 non-null int64
# PAY_AMT3                      30000 non-null int64
# PAY_AMT4                      30000 non-null int64
# PAY_AMT5                      30000 non-null int64
# PAY_AMT6                      30000 non-null int64
# default payment next month    30000 non-null int64
# dtypes: int64(24)
# memory usage: 5.5 MB

# %%
df.isnull().sum()
# Out:
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
df.describe().T
# Out:
#                               count           mean            std       min  \
# LIMIT_BAL                   30000.0  167484.322667  129747.661567   10000.0
# SEX                         30000.0       1.603733       0.489129       1.0
# EDUCATION                   30000.0       1.853133       0.790349       0.0
# MARRIAGE                    30000.0       1.551867       0.521970       0.0
# AGE                         30000.0      35.485500       9.217904      21.0
# PAY_0                       30000.0      -0.016700       1.123802      -2.0
# PAY_2                       30000.0      -0.133767       1.197186      -2.0
# PAY_3                       30000.0      -0.166200       1.196868      -2.0
# PAY_4                       30000.0      -0.220667       1.169139      -2.0
# PAY_5                       30000.0      -0.266200       1.133187      -2.0
# PAY_6                       30000.0      -0.291100       1.149988      -2.0
# BILL_AMT1                   30000.0   51223.330900   73635.860576 -165580.0
# BILL_AMT2                   30000.0   49179.075167   71173.768783  -69777.0
# BILL_AMT3                   30000.0   47013.154800   69349.387427 -157264.0
# BILL_AMT4                   30000.0   43262.948967   64332.856134 -170000.0
# BILL_AMT5                   30000.0   40311.400967   60797.155770  -81334.0
# BILL_AMT6                   30000.0   38871.760400   59554.107537 -339603.0
# PAY_AMT1                    30000.0    5663.580500   16563.280354       0.0
# PAY_AMT2                    30000.0    5921.163500   23040.870402       0.0
# PAY_AMT3                    30000.0    5225.681500   17606.961470       0.0
# PAY_AMT4                    30000.0    4826.076867   15666.159744       0.0
# PAY_AMT5                    30000.0    4799.387633   15278.305679       0.0
# PAY_AMT6                    30000.0    5215.502567   17777.465775       0.0
# default payment next month  30000.0       0.221200       0.415062       0.0
#
#                                  25%       50%        75%        max
# LIMIT_BAL                   50000.00  140000.0  240000.00  1000000.0
# SEX                             1.00       2.0       2.00        2.0
# EDUCATION                       1.00       2.0       2.00        6.0
# MARRIAGE                        1.00       2.0       2.00        3.0
# AGE                            28.00      34.0      41.00       79.0
# PAY_0                          -1.00       0.0       0.00        8.0
# PAY_2                          -1.00       0.0       0.00        8.0
# PAY_3                          -1.00       0.0       0.00        8.0
# PAY_4                          -1.00       0.0       0.00        8.0
# PAY_5                          -1.00       0.0       0.00        8.0
# PAY_6                          -1.00       0.0       0.00        8.0
# BILL_AMT1                    3558.75   22381.5   67091.00   964511.0
# BILL_AMT2                    2984.75   21200.0   64006.25   983931.0
# BILL_AMT3                    2666.25   20088.5   60164.75  1664089.0
# BILL_AMT4                    2326.75   19052.0   54506.00   891586.0
# BILL_AMT5                    1763.00   18104.5   50190.50   927171.0
# BILL_AMT6                    1256.00   17071.0   49198.25   961664.0
# PAY_AMT1                     1000.00    2100.0    5006.00   873552.0
# PAY_AMT2                      833.00    2009.0    5000.00  1684259.0
# PAY_AMT3                      390.00    1800.0    4505.00   896040.0
# PAY_AMT4                      296.00    1500.0    4013.25   621000.0
# PAY_AMT5                      252.50    1500.0    4031.50   426529.0
# PAY_AMT6                      117.75    1500.0    4000.00   528666.0
# default payment next month      0.00       0.0       0.00        1.0

# %%
sns.pairplot(df)

# %% [markdown]
# from the pairplot above, we can observe relationhip between the feature columns. To confirm that we would like plot a heatmap correlation.

# %%
plt.figure(figsize=(16,12))
sns.heatmap(df.corr(), annot = True,cmap = 'viridis' )

# %% [markdown]
# From the correlation heatmap above, it can be seen that there are some relationships between the feature columns, they are not entirely independent.
#
# But in this scenario, there is a correlation because a customer who was not able to pay the bill for 1 month was again not able to pay it for the subsequent months and hence the correlation.
#
# Again for the bill amount column, the same has happened. If the customer was not able to pay the bill, then the bill amount almost remained the same, or if the customer was able to pay then the bill amount got reduced.
#
# We remove columns when they convey the same information. But here, **dropping the columns shall result in the loss of bill and payment history data.** So, we don’t need to drop any column although there is a correlation.

# %% [markdown]
# ### Elbow Curve

# %%
from sklearn.cluster import KMeans
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(df.drop('default payment next month',axis=1))
    wcss.append(kmeans.inertia_)
    
#Plotting the results onto a line graph, allowing us to observe 'The elbow'
plt.figure(figsize=(12,9))
plt.plot(range(1, 11), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') #within cluster sum of squares
plt.show()

# %% [markdown]
# # general method

# %%
x=df.drop(labels=['default payment next month'],axis=1)
y=df['default payment next month']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
train_scaler=StandardScaler()
test_scaler=StandardScaler()

# %%
scaled_train_data=train_scaler.fit_transform(x_train)
scaled_test_data=test_scaler.fit_transform(x_test)

# %%
scaled_train_df=pd.DataFrame(data=scaled_train_data, columns=x_train.columns, index=x_train.index)

# %%
scaled_test_df=pd.DataFrame(data=scaled_test_data, columns=x_test.columns, index=x_test.index)

# %%
scaled_train_df.head()
# Out:
#        LIMIT_BAL       SEX  EDUCATION  MARRIAGE       AGE     PAY_0     PAY_2  \
# 16831  -0.365093 -1.238563   1.448725 -1.054777  1.464785  0.015441 -0.724837
# 4222   -1.061279 -1.238563  -1.073197  0.861786  0.271955  1.794063  0.110028
# 8736   -0.597155  0.807387   0.187764  0.861786  0.380394  0.015441  0.110028
# 27880  -0.287739  0.807387   1.448725 -1.054777 -1.029313  0.015441  0.110028
# 29290  -0.906571 -1.238563   1.448725  0.861786 -1.029313  1.794063  0.110028
#
#           PAY_3     PAY_4     PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 16831 -0.697423 -0.668007 -0.647249  ...  -0.642576  -0.661257  -0.529514
# 4222   0.141588  0.189890  0.238910  ...   0.228168   0.224623   0.099678
# 8736   0.141588  0.189890  0.238910  ...  -0.067356  -0.081444  -0.154738
# 27880  1.819611  1.905684  2.011229  ...   1.169781   1.409281   1.438216
# 29290  0.141588  0.189890  0.238910  ...  -0.068136  -0.166675  -0.389455
#
#        BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 16831  -0.579208 -0.105018 -0.145558 -0.242409  0.201062 -0.014852 -0.233621
# 4222    0.583327 -0.095828 -0.039170  0.152840 -0.212528  2.237818  0.268573
# 8736   -0.181984 -0.213650 -0.157335 -0.219417 -0.239691 -0.231210 -0.254511
# 27880   1.562072  0.316551 -0.133702  0.207584 -0.302252  0.074237 -0.012958
# 29290  -0.369159 -0.210882 -0.010496 -0.213942 -0.228875 -0.268309 -0.257889
#
# [5 rows x 23 columns]

# %% [markdown]
# # naive bayes classification

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()

# %%
pred_y=gnb.fit(scaled_train_df,y_train).predict(scaled_test_df)

# %%
from sklearn.metrics import accuracy_score

# %%
ac=accuracy_score(y_test, pred_y)
ac
# Out:
# 0.6603030303030303

# %% [markdown]
# **HyperParameter Tuning**

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {"var_smoothing": [1e-9,0.1, 0.001, 0.5, 0.05,0.01,1e-8,1e-7,1e-6,1e-10,1e-11]}
#Creating an object of the Grid Search class
grid = GridSearchCV(estimator=gnb, param_grid=param_grid, cv=5,  verbose=3)

# %%
#finding the best parameters
grid.fit(scaled_train_data, y_train)
# Out:
# Fitting 5 folds for each of 11 candidates, totalling 55 fits
# [CV] var_smoothing=1e-09 .............................................
# [CV] ................. var_smoothing=1e-09, score=0.580, total=   0.0s
# [CV] var_smoothing=1e-09 .............................................
# [CV] ................. var_smoothing=1e-09, score=0.665, total=   0.0s
# [CV] var_smoothing=1e-09 .............................................
# [CV] ................. var_smoothing=1e-09, score=0.714, total=   0.0s
# [CV] var_smoothing=1e-09 .............................................
# [CV] ................. var_smoothing=1e-09, score=0.646, total=   0.0s
# [CV] var_smoothing=1e-09 .............................................
# [CV] ................. var_smoothing=1e-09, score=0.689, total=   0.0s
# [CV] var_smoothing=0.1 ...............................................
# [CV] ................... var_smoothing=0.1, score=0.665, total=   0.0s
# [CV] var_smoothing=0.1 ...............................................
# [CV] ................... var_smoothing=0.1, score=0.743, total=   0.0s
# [CV] var_smoothing=0.1 ...............................................
# [CV] ................... var_smoothing=0.1, score=0.769, total=   0.0s
# [CV] var_smoothing=0.1 ...............................................
# [CV] ................... var_smoothing=0.1, score=0.740, total=   0.0s
# [CV] var_smoothing=0.1 ...............................................
# [CV] ................... var_smoothing=0.1, score=0.754, total=   0.0s
# [CV] var_smoothing=0.001 .............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [CV] ................. var_smoothing=0.001, score=0.581, total=   0.0s
# [CV] var_smoothing=0.001 .............................................
# [CV] ................. var_smoothing=0.001, score=0.666, total=   0.0s
# [CV] var_smoothing=0.001 .............................................
# [CV] ................. var_smoothing=0.001, score=0.716, total=   0.0s
# [CV] var_smoothing=0.001 .............................................
# [CV] ................. var_smoothing=0.001, score=0.647, total=   0.0s
# [CV] var_smoothing=0.001 .............................................
# [CV] ................. var_smoothing=0.001, score=0.691, total=   0.0s
# [CV] var_smoothing=0.5 ...............................................
# [CV] ................... var_smoothing=0.5, score=0.783, total=   0.0s
# [CV] var_smoothing=0.5 ...............................................
# [CV] ................... var_smoothing=0.5, score=0.784, total=   0.0s
# [CV] var_smoothing=0.5 ...............................................
# [CV] ................... var_smoothing=0.5, score=0.794, total=   0.0s
# [CV] var_smoothing=0.5 ...............................................
# [CV] ................... var_smoothing=0.5, score=0.783, total=   0.0s
# [CV] var_smoothing=0.5 ...............................................
# [CV] ................... var_smoothing=0.5, score=0.781, total=   0.0s
# [CV] var_smoothing=0.05 ..............................................
# [CV] .................. var_smoothing=0.05, score=0.623, total=   0.1s
# [CV] var_smoothing=0.05 ..............................................
# [CV] .................. var_smoothing=0.05, score=0.711, total=   0.0s
# [CV] var_smoothing=0.05 ..............................................
# [CV] .................. var_smoothing=0.05, score=0.746, total=   0.0s
# [CV] var_smoothing=0.05 ..............................................
# [CV] .................. var_smoothing=0.05, score=0.702, total=   0.0s
# [CV] var_smoothing=0.05 ..............................................
# [CV] .................. var_smoothing=0.05, score=0.733, total=   0.0s
# [CV] var_smoothing=0.01 ..............................................
# [CV] .................. var_smoothing=0.01, score=0.586, total=   0.0s
# [CV] var_smoothing=0.01 ..............................................
# [CV] .................. var_smoothing=0.01, score=0.671, total=   0.0s
# [CV] var_smoothing=0.01 ..............................................
# [CV] .................. var_smoothing=0.01, score=0.723, total=   0.0s
# [CV] var_smoothing=0.01 ..............................................
# [CV] .................. var_smoothing=0.01, score=0.656, total=   0.0s
# [CV] var_smoothing=0.01 ..............................................
# [CV] .................. var_smoothing=0.01, score=0.698, total=   0.0s
# [CV] var_smoothing=1e-08 .............................................
# [CV] ................. var_smoothing=1e-08, score=0.580, total=   0.0s
# [CV] var_smoothing=1e-08 .............................................
# [CV] ................. var_smoothing=1e-08, score=0.665, total=   0.0s
# [CV] var_smoothing=1e-08 .............................................
# [CV] ................. var_smoothing=1e-08, score=0.714, total=   0.0s
# [CV] var_smoothing=1e-08 .............................................
# [CV] ................. var_smoothing=1e-08, score=0.646, total=   0.0s
# [CV] var_smoothing=1e-08 .............................................
# [CV] ................. var_smoothing=1e-08, score=0.689, total=   0.0s
# [CV] var_smoothing=1e-07 .............................................
# [CV] ................. var_smoothing=1e-07, score=0.580, total=   0.0s
# [CV] var_smoothing=1e-07 .............................................
# [CV] ................. var_smoothing=1e-07, score=0.665, total=   0.0s
# [CV] var_smoothing=1e-07 .............................................
# [CV] ................. var_smoothing=1e-07, score=0.714, total=   0.0s
# [CV] var_smoothing=1e-07 .............................................
# [CV] ................. var_smoothing=1e-07, score=0.646, total=   0.0s
# [CV] var_smoothing=1e-07 .............................................
# [CV] ................. var_smoothing=1e-07, score=0.689, total=   0.0s
# [CV] var_smoothing=1e-06 .............................................
# [CV] ................. var_smoothing=1e-06, score=0.580, total=   0.0s
# [CV] var_smoothing=1e-06 .............................................
# [CV] ................. var_smoothing=1e-06, score=0.665, total=   0.0s
# [CV] var_smoothing=1e-06 .............................................
# [CV] ................. var_smoothing=1e-06, score=0.714, total=   0.0s
# [CV] var_smoothing=1e-06 .............................................
# [CV] ................. var_smoothing=1e-06, score=0.646, total=   0.0s
# [CV] var_smoothing=1e-06 .............................................
# [CV] ................. var_smoothing=1e-06, score=0.689, total=   0.0s
# [CV] var_smoothing=1e-10 .............................................
# [CV] ................. var_smoothing=1e-10, score=0.580, total=   0.0s
# [CV] var_smoothing=1e-10 .............................................
# [CV] ................. var_smoothing=1e-10, score=0.665, total=   0.0s
# [CV] var_smoothing=1e-10 .............................................
# [CV] ................. var_smoothing=1e-10, score=0.714, total=   0.0s
# [CV] var_smoothing=1e-10 .............................................
# [CV] ................. var_smoothing=1e-10, score=0.646, total=   0.0s
# [CV] var_smoothing=1e-10 .............................................
# [CV] ................. var_smoothing=1e-10, score=0.689, total=   0.0s
# [CV] var_smoothing=1e-11 .............................................
# [CV] ................. var_smoothing=1e-11, score=0.580, total=   0.0s
# [CV] var_smoothing=1e-11 .............................................
# [CV] ................. var_smoothing=1e-11, score=0.665, total=   0.0s
# [CV] var_smoothing=1e-11 .............................................
# [CV] ................. var_smoothing=1e-11, score=0.714, total=   0.0s
# [CV] var_smoothing=1e-11 .............................................
# [CV] ................. var_smoothing=1e-11, score=0.646, total=   0.0s
# [CV] var_smoothing=1e-11 .............................................
# [CV] ................. var_smoothing=1e-11, score=0.689, total=   0.0s
# [Parallel(n_jobs=1)]: Done  55 out of  55 | elapsed:    1.2s finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=GaussianNB(priors=None, var_smoothing=1e-09),
#              iid='deprecated', n_jobs=None,
#              param_grid={'var_smoothing': [1e-09, 0.1, 0.001, 0.5, 0.05, 0.01,
#                                            1e-08, 1e-07, 1e-06, 1e-10, 1e-11]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
grid.best_estimator_
# Out:
# GaussianNB(priors=None, var_smoothing=0.5)

# %%
gnb_new=GaussianNB(var_smoothing=0.5)
pred_y_new=gnb_new.fit(scaled_train_df,y_train).predict(scaled_test_df)

# %%
ac_new=accuracy_score(y_test,pred_y_new)
ac_new
# Out:
# 0.7798989898989899

# %% [markdown]
# ## Xgboost

# %%
from xgboost import XGBClassifier
param_grid_xgboost = {"n_estimators": [50,100, 130],
                      "max_depth": range(3, 11, 1),
                      "random_state":[0,50,100]}

# Creating an object of the Grid Search class
grid= GridSearchCV(XGBClassifier(objective='binary:logistic',use_label_encoder=False),
                   param_grid_xgboost, verbose=3,cv=5,n_jobs=-1)

# %%
grid.fit(scaled_train_df,y_train)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   30.0s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed: 17.4min finished
# [12:17:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# GridSearchCV(cv=5, error_score=nan,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, gamma=None,
#                                      gpu_id=None, importance_type='gain',
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estim...
#                                      random_state=None, reg_alpha=None,
#                                      reg_lambda=None, scale_pos_weight=None,
#                                      subsample=None, tree_method=None,
#                                      use_label_encoder=False,
#                                      validate_parameters=None, verbosity=None),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'max_depth': range(3, 11),
#                          'n_estimators': [50, 100, 130],
#                          'random_state': [0, 50, 100]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
grid.best_estimator_
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=50, n_jobs=4, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', use_label_encoder=False,
#               validate_parameters=1, verbosity=None)

# %%
xgb_new=XGBClassifier(base_score=0.5)

# %%
pred_y_xgb_new=xgb_new.fit(scaled_train_df,y_train).predict(scaled_test_df)
# Out:
# C:\Users\Srikiran\anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [12:17:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
ac_xgb_new=accuracy_score(y_test,pred_y_xgb_new)
ac_xgb_new
# Out:
# 0.8125252525252525
